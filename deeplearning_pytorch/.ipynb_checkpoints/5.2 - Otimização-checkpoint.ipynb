# %%
# !pip install sklearn torch matplotlib
# Out:
# Requirement already satisfied: sklearn in /home/neto/projects/jupyter-notebook/venv/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: torch in /home/neto/projects/jupyter-notebook/venv/lib/python3.8/site-packages (1.8.1)
# Collecting matplotlib
#   Using cached matplotlib-3.4.2-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
# Requirement already satisfied: scikit-learn in /home/neto/projects/jupyter-notebook/venv/lib/python3.8/site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: typing-extensions in /home/neto/projects/jupyter-notebook/venv/lib/python3.8/site-packages (from torch) (3.10.0.0)
# Requirement already satisfied: numpy in /home/neto/projects/jupyter-notebook/venv/lib/python3.8/site-packages (from torch) (1.20.3)
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-8.2.0-cp38-cp38-manylinux1_x86_64.whl (3.0 MB)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/neto/projects/jupyter-notebook/venv/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/neto/projects/jupyter-notebook/venv/lib/python3.8/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: six in /home/neto/projects/jupyter-notebook/venv/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/neto/projects/jupyter-notebook/venv/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/neto/projects/jupyter-notebook/venv/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in /home/neto/projects/jupyter-notebook/venv/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.6.3)
# Installing collected packages: pillow, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 pillow-8.2.0

# %%
from sklearn import datasets
import matplotlib.pyplot as plt

features = [0, 9]

wine = datasets.load_wine()
data = wine.data[:, features]
targets = wine.target

plt.scatter(data[:, 0], data[:,1], c=targets, s=15, cmap=plt.cm.brg)
plt.xlabel(wine.feature_names[features[0]])
plt.ylabel(wine.feature_names[features[1]])
# Out:
# Text(0, 0.5, 'color_intensity')

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data = scaler.fit_transform(data)

plt.scatter(data[:, 0], data[:,1], c=targets, s=15, cmap=plt.cm.brg)
plt.xlabel(wine.feature_names[features[0]])
plt.ylabel(wine.feature_names[features[1]])
# Out:
# Text(0, 0.5, 'color_intensity')
