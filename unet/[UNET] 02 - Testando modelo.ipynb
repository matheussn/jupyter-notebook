# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import os
import cv2
import re
import numpy as np
from tensorflow.keras.backend import int_shape
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D, UpSampling2D, UpSampling3D, Add, BatchNormalization, Input, Activation, Lambda, Concatenate
from tensorflow import keras

# %%
# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# %%
threshold = 0.5
metric = keras.metrics.MeanIoU(num_classes=2)
def mean_iou_threshold(y_true, y_pred):
    y_pred = y_pred.numpy()
    y_pred[y_pred > threshold]= 1
    y_pred[y_pred <= threshold] = 0
    metric.reset_states()
    metric.update_state(y_true, y_pred)
    return metric.result().numpy()
# Out:
# 2021-10-15 08:06:52.624791: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-15 08:06:52.684900: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-15 08:06:52.685366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-15 08:06:52.686737: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-15 08:06:52.722334: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-15 08:06:52.723279: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-15 08:06:52.724100: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-15 08:06:53.788670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-15 08:06:53.788918: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-15 08:06:53.789127: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-15 08:06:53.789778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2973 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
def bgr_to_rgb(img):
    b,g,r = cv2.split(img)
    return cv2.merge([r,g,b])

def get_label(file: str, labels: dict):
    match = re.search('[a-z]+', file).group(0)
    return labels[match]

def load_all_imgs(path, img_size, mode):
    imgs = []
    files = os.listdir(path)
    files.sort()
    print(f'\n{path} found {len(files)} img to load')
    for index, file in enumerate(files):
        img_path = os.path.join(path, file)
        img = cv2.imread(img_path, mode)
        
        if mode == 0:
            img = np.expand_dims(img, 2)
        
        if mode == 1:
            img = bgr_to_rgb(img)
        img = cv2.resize(img, img_size)
        img = img / 255.
        imgs.append(img)
        if index % 100 == 0:
            print(f'\n[{index}]:', end='')
        else:
            print("|", end='')
    return np.array(imgs)

# %%
def res_unet(filter_root, depth, n_class=2, input_size=(256, 256, 1), activation='relu', batch_norm=True, final_activation='softmax'):
    """
    Build UNet model with ResBlock.
    Args:
        filter_root (int): Number of filters to start with in first convolution.
        depth (int): How deep to go in UNet i.e. how many down and up sampling you want to do in the model. 
                    Filter root and image size should be multiple of 2^depth.
        n_class (int, optional): How many classes in the output layer. Defaults to 2.
        input_size (tuple, optional): Input image size. Defaults to (256, 256, 1).
        activation (str, optional): activation to use in each convolution. Defaults to 'relu'.
        batch_norm (bool, optional): To use Batch normaliztion or not. Defaults to True.
        final_activation (str, optional): activation for output layer. Defaults to 'softmax'.
    Returns:
        obj: keras model object
    """
    inputs = Input(input_size)
    x = inputs
    # Dictionary for long connections
    long_connection_store = {}

    if len(input_size) == 3:
        Conv = Conv2D
        MaxPooling = MaxPooling2D
        UpSampling = UpSampling2D
    elif len(input_size) == 4:
        Conv = Conv3D
        MaxPooling = MaxPooling3D
        UpSampling = UpSampling3D

    # Down sampling
    for i in range(depth):
        out_channel = 2**i * filter_root

        # Residual/Skip connection
        res = Conv(out_channel, kernel_size=1, padding='same', use_bias=False, name="Identity{}_1".format(i))(x)

        # First Conv Block with Conv, BN and activation
        conv1 = Conv(out_channel, kernel_size=3, padding='same', name="Conv{}_1".format(i))(x)
        if batch_norm:
            conv1 = BatchNormalization(name="BN{}_1".format(i))(conv1)
        act1 = Activation(activation, name="Act{}_1".format(i))(conv1)

        # Second Conv block with Conv and BN only
        conv2 = Conv(out_channel, kernel_size=3, padding='same', name="Conv{}_2".format(i))(act1)
        if batch_norm:
            conv2 = BatchNormalization(name="BN{}_2".format(i))(conv2)

        resconnection = Add(name="Add{}_1".format(i))([res, conv2])

        act2 = Activation(activation, name="Act{}_2".format(i))(resconnection)

        # Max pooling
        if i < depth - 1:
            long_connection_store[str(i)] = act2
            x = MaxPooling(padding='same', name="MaxPooling{}_1".format(i))(act2)
        else:
            x = act2

    # Upsampling
    for i in range(depth - 2, -1, -1):
        out_channel = 2**(i) * filter_root

        # long connection from down sampling path.
        long_connection = long_connection_store[str(i)]

        up1 = UpSampling(name="UpSampling{}_1".format(i))(x)
        up_conv1 = Conv(out_channel, 2, activation='relu', padding='same', name="upConv{}_1".format(i))(up1)

        #  Concatenate.
        up_conc = Concatenate(axis=-1, name="upConcatenate{}_1".format(i))([up_conv1, long_connection])

        #  Convolutions
        up_conv2 = Conv(out_channel, 3, padding='same', name="upConv{}_2".format(i))(up_conc)
        if batch_norm:
            up_conv2 = BatchNormalization(name="upBN{}_1".format(i))(up_conv2)
        up_act1 = Activation(activation, name="upAct{}_1".format(i))(up_conv2)

        up_conv2 = Conv(out_channel, 3, padding='same', name="upConv{}_3".format(i))(up_act1)
        if batch_norm:
            up_conv2 = BatchNormalization(name="upBN{}_2".format(i))(up_conv2)

        # Residual/Skip connection
        res = Conv(out_channel, kernel_size=1, padding='same', use_bias=False, name="upIdentity{}_1".format(i))(up_conc)

        resconnection = Add(name="upAdd{}_1".format(i))([res, up_conv2])

        x = Activation(activation, name="upAct{}_2".format(i))(resconnection)

    # Final convolution
    output = Conv(n_class, 1, padding='same', activation=final_activation, name='output')(x)

    return Model(inputs, outputs=output, name='Res-UNet')

# %%
model = res_unet(32, 5, input_size=(128, 128, 3), n_class=1,final_activation='sigmoid')
model.compile(run_eagerly=True,optimizer="adam", loss="binary_crossentropy", metrics=mean_iou_threshold)

# %%
model.summary()
# Out:
# Model: "Res-UNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# Conv0_1 (Conv2D)                (None, 128, 128, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# BN0_1 (BatchNormalization)      (None, 128, 128, 32) 128         Conv0_1[0][0]
# __________________________________________________________________________________________________
# Act0_1 (Activation)             (None, 128, 128, 32) 0           BN0_1[0][0]
# __________________________________________________________________________________________________
# Conv0_2 (Conv2D)                (None, 128, 128, 32) 9248        Act0_1[0][0]
# __________________________________________________________________________________________________
# Identity0_1 (Conv2D)            (None, 128, 128, 32) 96          input_1[0][0]
# __________________________________________________________________________________________________
# BN0_2 (BatchNormalization)      (None, 128, 128, 32) 128         Conv0_2[0][0]
# __________________________________________________________________________________________________
# Add0_1 (Add)                    (None, 128, 128, 32) 0           Identity0_1[0][0]
#                                                                  BN0_2[0][0]
# __________________________________________________________________________________________________
# Act0_2 (Activation)             (None, 128, 128, 32) 0           Add0_1[0][0]
# __________________________________________________________________________________________________
# MaxPooling0_1 (MaxPooling2D)    (None, 64, 64, 32)   0           Act0_2[0][0]
# __________________________________________________________________________________________________
# Conv1_1 (Conv2D)                (None, 64, 64, 64)   18496       MaxPooling0_1[0][0]
# __________________________________________________________________________________________________
# BN1_1 (BatchNormalization)      (None, 64, 64, 64)   256         Conv1_1[0][0]
# __________________________________________________________________________________________________
# Act1_1 (Activation)             (None, 64, 64, 64)   0           BN1_1[0][0]
# __________________________________________________________________________________________________
# Conv1_2 (Conv2D)                (None, 64, 64, 64)   36928       Act1_1[0][0]
# __________________________________________________________________________________________________
# Identity1_1 (Conv2D)            (None, 64, 64, 64)   2048        MaxPooling0_1[0][0]
# __________________________________________________________________________________________________
# BN1_2 (BatchNormalization)      (None, 64, 64, 64)   256         Conv1_2[0][0]
# __________________________________________________________________________________________________
# Add1_1 (Add)                    (None, 64, 64, 64)   0           Identity1_1[0][0]
#                                                                  BN1_2[0][0]
# __________________________________________________________________________________________________
# Act1_2 (Activation)             (None, 64, 64, 64)   0           Add1_1[0][0]
# __________________________________________________________________________________________________
# MaxPooling1_1 (MaxPooling2D)    (None, 32, 32, 64)   0           Act1_2[0][0]
# __________________________________________________________________________________________________
# Conv2_1 (Conv2D)                (None, 32, 32, 128)  73856       MaxPooling1_1[0][0]
# __________________________________________________________________________________________________
# BN2_1 (BatchNormalization)      (None, 32, 32, 128)  512         Conv2_1[0][0]
# __________________________________________________________________________________________________
# Act2_1 (Activation)             (None, 32, 32, 128)  0           BN2_1[0][0]
# __________________________________________________________________________________________________
# Conv2_2 (Conv2D)                (None, 32, 32, 128)  147584      Act2_1[0][0]
# __________________________________________________________________________________________________
# Identity2_1 (Conv2D)            (None, 32, 32, 128)  8192        MaxPooling1_1[0][0]
# __________________________________________________________________________________________________
# BN2_2 (BatchNormalization)      (None, 32, 32, 128)  512         Conv2_2[0][0]
# __________________________________________________________________________________________________
# Add2_1 (Add)                    (None, 32, 32, 128)  0           Identity2_1[0][0]
#                                                                  BN2_2[0][0]
# __________________________________________________________________________________________________
# Act2_2 (Activation)             (None, 32, 32, 128)  0           Add2_1[0][0]
# __________________________________________________________________________________________________
# MaxPooling2_1 (MaxPooling2D)    (None, 16, 16, 128)  0           Act2_2[0][0]
# __________________________________________________________________________________________________
# Conv3_1 (Conv2D)                (None, 16, 16, 256)  295168      MaxPooling2_1[0][0]
# __________________________________________________________________________________________________
# BN3_1 (BatchNormalization)      (None, 16, 16, 256)  1024        Conv3_1[0][0]
# __________________________________________________________________________________________________
# Act3_1 (Activation)             (None, 16, 16, 256)  0           BN3_1[0][0]
# __________________________________________________________________________________________________
# Conv3_2 (Conv2D)                (None, 16, 16, 256)  590080      Act3_1[0][0]
# __________________________________________________________________________________________________
# Identity3_1 (Conv2D)            (None, 16, 16, 256)  32768       MaxPooling2_1[0][0]
# __________________________________________________________________________________________________
# BN3_2 (BatchNormalization)      (None, 16, 16, 256)  1024        Conv3_2[0][0]
# __________________________________________________________________________________________________
# Add3_1 (Add)                    (None, 16, 16, 256)  0           Identity3_1[0][0]
#                                                                  BN3_2[0][0]
# __________________________________________________________________________________________________
# Act3_2 (Activation)             (None, 16, 16, 256)  0           Add3_1[0][0]
# __________________________________________________________________________________________________
# MaxPooling3_1 (MaxPooling2D)    (None, 8, 8, 256)    0           Act3_2[0][0]
# __________________________________________________________________________________________________
# Conv4_1 (Conv2D)                (None, 8, 8, 512)    1180160     MaxPooling3_1[0][0]
# __________________________________________________________________________________________________
# BN4_1 (BatchNormalization)      (None, 8, 8, 512)    2048        Conv4_1[0][0]
# __________________________________________________________________________________________________
# Act4_1 (Activation)             (None, 8, 8, 512)    0           BN4_1[0][0]
# __________________________________________________________________________________________________
# Conv4_2 (Conv2D)                (None, 8, 8, 512)    2359808     Act4_1[0][0]
# __________________________________________________________________________________________________
# Identity4_1 (Conv2D)            (None, 8, 8, 512)    131072      MaxPooling3_1[0][0]
# __________________________________________________________________________________________________
# BN4_2 (BatchNormalization)      (None, 8, 8, 512)    2048        Conv4_2[0][0]
# __________________________________________________________________________________________________
# Add4_1 (Add)                    (None, 8, 8, 512)    0           Identity4_1[0][0]
#                                                                  BN4_2[0][0]
# __________________________________________________________________________________________________
# Act4_2 (Activation)             (None, 8, 8, 512)    0           Add4_1[0][0]
# __________________________________________________________________________________________________
# UpSampling3_1 (UpSampling2D)    (None, 16, 16, 512)  0           Act4_2[0][0]
# __________________________________________________________________________________________________
# upConv3_1 (Conv2D)              (None, 16, 16, 256)  524544      UpSampling3_1[0][0]
# __________________________________________________________________________________________________
# upConcatenate3_1 (Concatenate)  (None, 16, 16, 512)  0           upConv3_1[0][0]
#                                                                  Act3_2[0][0]
# __________________________________________________________________________________________________
# upConv3_2 (Conv2D)              (None, 16, 16, 256)  1179904     upConcatenate3_1[0][0]
# __________________________________________________________________________________________________
# upBN3_1 (BatchNormalization)    (None, 16, 16, 256)  1024        upConv3_2[0][0]
# __________________________________________________________________________________________________
# upAct3_1 (Activation)           (None, 16, 16, 256)  0           upBN3_1[0][0]
# __________________________________________________________________________________________________
# upConv3_3 (Conv2D)              (None, 16, 16, 256)  590080      upAct3_1[0][0]
# __________________________________________________________________________________________________
# upIdentity3_1 (Conv2D)          (None, 16, 16, 256)  131072      upConcatenate3_1[0][0]
# __________________________________________________________________________________________________
# upBN3_2 (BatchNormalization)    (None, 16, 16, 256)  1024        upConv3_3[0][0]
# __________________________________________________________________________________________________
# upAdd3_1 (Add)                  (None, 16, 16, 256)  0           upIdentity3_1[0][0]
#                                                                  upBN3_2[0][0]
# __________________________________________________________________________________________________
# upAct3_2 (Activation)           (None, 16, 16, 256)  0           upAdd3_1[0][0]
# __________________________________________________________________________________________________
# UpSampling2_1 (UpSampling2D)    (None, 32, 32, 256)  0           upAct3_2[0][0]
# __________________________________________________________________________________________________
# upConv2_1 (Conv2D)              (None, 32, 32, 128)  131200      UpSampling2_1[0][0]
# __________________________________________________________________________________________________
# upConcatenate2_1 (Concatenate)  (None, 32, 32, 256)  0           upConv2_1[0][0]
#                                                                  Act2_2[0][0]
# __________________________________________________________________________________________________
# upConv2_2 (Conv2D)              (None, 32, 32, 128)  295040      upConcatenate2_1[0][0]
# __________________________________________________________________________________________________
# upBN2_1 (BatchNormalization)    (None, 32, 32, 128)  512         upConv2_2[0][0]
# __________________________________________________________________________________________________
# upAct2_1 (Activation)           (None, 32, 32, 128)  0           upBN2_1[0][0]
# __________________________________________________________________________________________________
# upConv2_3 (Conv2D)              (None, 32, 32, 128)  147584      upAct2_1[0][0]
# __________________________________________________________________________________________________
# upIdentity2_1 (Conv2D)          (None, 32, 32, 128)  32768       upConcatenate2_1[0][0]
# __________________________________________________________________________________________________
# upBN2_2 (BatchNormalization)    (None, 32, 32, 128)  512         upConv2_3[0][0]
# __________________________________________________________________________________________________
# upAdd2_1 (Add)                  (None, 32, 32, 128)  0           upIdentity2_1[0][0]
#                                                                  upBN2_2[0][0]
# __________________________________________________________________________________________________
# upAct2_2 (Activation)           (None, 32, 32, 128)  0           upAdd2_1[0][0]
# __________________________________________________________________________________________________
# UpSampling1_1 (UpSampling2D)    (None, 64, 64, 128)  0           upAct2_2[0][0]
# __________________________________________________________________________________________________
# upConv1_1 (Conv2D)              (None, 64, 64, 64)   32832       UpSampling1_1[0][0]
# __________________________________________________________________________________________________
# upConcatenate1_1 (Concatenate)  (None, 64, 64, 128)  0           upConv1_1[0][0]
#                                                                  Act1_2[0][0]
# __________________________________________________________________________________________________
# upConv1_2 (Conv2D)              (None, 64, 64, 64)   73792       upConcatenate1_1[0][0]
# __________________________________________________________________________________________________
# upBN1_1 (BatchNormalization)    (None, 64, 64, 64)   256         upConv1_2[0][0]
# __________________________________________________________________________________________________
# upAct1_1 (Activation)           (None, 64, 64, 64)   0           upBN1_1[0][0]
# __________________________________________________________________________________________________
# upConv1_3 (Conv2D)              (None, 64, 64, 64)   36928       upAct1_1[0][0]
# __________________________________________________________________________________________________
# upIdentity1_1 (Conv2D)          (None, 64, 64, 64)   8192        upConcatenate1_1[0][0]
# __________________________________________________________________________________________________
# upBN1_2 (BatchNormalization)    (None, 64, 64, 64)   256         upConv1_3[0][0]
# __________________________________________________________________________________________________
# upAdd1_1 (Add)                  (None, 64, 64, 64)   0           upIdentity1_1[0][0]
#                                                                  upBN1_2[0][0]
# __________________________________________________________________________________________________
# upAct1_2 (Activation)           (None, 64, 64, 64)   0           upAdd1_1[0][0]
# __________________________________________________________________________________________________
# UpSampling0_1 (UpSampling2D)    (None, 128, 128, 64) 0           upAct1_2[0][0]
# __________________________________________________________________________________________________
# upConv0_1 (Conv2D)              (None, 128, 128, 32) 8224        UpSampling0_1[0][0]
# __________________________________________________________________________________________________
# upConcatenate0_1 (Concatenate)  (None, 128, 128, 64) 0           upConv0_1[0][0]
#                                                                  Act0_2[0][0]
# __________________________________________________________________________________________________
# upConv0_2 (Conv2D)              (None, 128, 128, 32) 18464       upConcatenate0_1[0][0]
# __________________________________________________________________________________________________
# upBN0_1 (BatchNormalization)    (None, 128, 128, 32) 128         upConv0_2[0][0]
# __________________________________________________________________________________________________
# upAct0_1 (Activation)           (None, 128, 128, 32) 0           upBN0_1[0][0]
# __________________________________________________________________________________________________
# upConv0_3 (Conv2D)              (None, 128, 128, 32) 9248        upAct0_1[0][0]
# __________________________________________________________________________________________________
# upIdentity0_1 (Conv2D)          (None, 128, 128, 32) 2048        upConcatenate0_1[0][0]
# __________________________________________________________________________________________________
# upBN0_2 (BatchNormalization)    (None, 128, 128, 32) 128         upConv0_3[0][0]
# __________________________________________________________________________________________________
# upAdd0_1 (Add)                  (None, 128, 128, 32) 0           upIdentity0_1[0][0]
#                                                                  upBN0_2[0][0]
# __________________________________________________________________________________________________
# upAct0_2 (Activation)           (None, 128, 128, 32) 0           upAdd0_1[0][0]
# __________________________________________________________________________________________________
# output (Conv2D)                 (None, 128, 128, 1)  33          upAct0_2[0][0]
# ==================================================================================================
# Total params: 8,120,129
# Trainable params: 8,114,241
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
import tensorflow as tf

tf.keras.utils.plot_model(model, to_file="model.png", show_shapes=True)

# %%
img_size = (128, 128)
input_dir = "../dataset/segmentation/all_seg/"
target_dir = "../dataset/segmentation/annotation/all/"
num_classes = 1
batch_size = 10
epochs = 200

# %%
# Load images
trainImgs = load_all_imgs(input_dir,img_size, 1)
validImgs = load_all_imgs(target_dir,img_size, 0)
# Out:
# ../dataset/segmentation/all_seg/ found 120 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||
# ../dataset/segmentation/annotation/all/ found 120 img to load
#
# [0]:|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# [100]:|||||||||||||||||||

# %%
img_to_test = int(len(trainImgs) * 0.8)
x_train = trainImgs[0:img_to_test]
y_train = validImgs[0:img_to_test]
x_val = trainImgs[img_to_test:]
y_val = validImgs[img_to_test:]
validation_data = (x_val, y_val)
print("ImgToTest:",img_to_test)
print("Validation_data_size:", len(validation_data[0]))
# Out:
# ImgToTest: 96
# Validation_data_size: 24

# %%
plt.imshow(trainImgs[0])

# %%
pred = model.predict(x_train)
# Out:
# 2021-10-15 08:07:48.527515: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-15 08:07:49.712099: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8204

# %%
pred.shape
# Out:
# (96, 128, 128, 1)

# %%
plt.imshow(pred[0], cmap='gray')

# %%
from matplotlib.colors import NoNorm
predict_img = pred[80]
predict_img[predict_img > 0.5] = 1
predict_img[predict_img <= 0.5] = 0

plt.imshow(predict_img, cmap='gray', norm=NoNorm())

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint("oxford_segmentation.h5", save_best_only=True)
]

# Train the model, doing validation at the end of each epoch.
model.fit(x_train, y_train, batch_size=batch_size,epochs=epochs, validation_data=validation_data, callbacks=callbacks)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 9s 616ms/step - loss: 0.5183 - mean_iou_threshold: 0.5624 - val_loss: 0.5833 - val_mean_iou_threshold: 0.3842
# /home/neto/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.4081 - mean_iou_threshold: 0.6485 - val_loss: 0.5902 - val_mean_iou_threshold: 0.3842
# Epoch 3/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.3819 - mean_iou_threshold: 0.6703 - val_loss: 0.5923 - val_mean_iou_threshold: 0.3871
# Epoch 4/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.3550 - mean_iou_threshold: 0.6959 - val_loss: 1.2642 - val_mean_iou_threshold: 0.3851
# Epoch 5/200
# 10/10 [==============================] - 3s 256ms/step - loss: 0.3557 - mean_iou_threshold: 0.6965 - val_loss: 1.0924 - val_mean_iou_threshold: 0.3842
# Epoch 6/200
# 10/10 [==============================] - 3s 256ms/step - loss: 0.3420 - mean_iou_threshold: 0.7045 - val_loss: 0.9403 - val_mean_iou_threshold: 0.3842
# Epoch 7/200
# 10/10 [==============================] - 2s 251ms/step - loss: 0.3370 - mean_iou_threshold: 0.7083 - val_loss: 0.6572 - val_mean_iou_threshold: 0.3843
# Epoch 8/200
# 10/10 [==============================] - 3s 250ms/step - loss: 0.3267 - mean_iou_threshold: 0.7156 - val_loss: 0.5653 - val_mean_iou_threshold: 0.3862
# Epoch 9/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.3081 - mean_iou_threshold: 0.7311 - val_loss: 0.7050 - val_mean_iou_threshold: 0.3842
# Epoch 10/200
# 10/10 [==============================] - 2s 249ms/step - loss: 0.3057 - mean_iou_threshold: 0.7375 - val_loss: 0.6073 - val_mean_iou_threshold: 0.4015
# Epoch 11/200
# 10/10 [==============================] - 2s 250ms/step - loss: 0.2911 - mean_iou_threshold: 0.7433 - val_loss: 1.1560 - val_mean_iou_threshold: 0.3842
# Epoch 12/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.2835 - mean_iou_threshold: 0.7518 - val_loss: 1.4740 - val_mean_iou_threshold: 0.3842
# Epoch 13/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.2934 - mean_iou_threshold: 0.7390 - val_loss: 0.8403 - val_mean_iou_threshold: 0.3842
# Epoch 14/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.2718 - mean_iou_threshold: 0.7596 - val_loss: 1.1330 - val_mean_iou_threshold: 0.3842
# Epoch 15/200
# 10/10 [==============================] - 2s 250ms/step - loss: 0.2633 - mean_iou_threshold: 0.7635 - val_loss: 1.1605 - val_mean_iou_threshold: 0.3842
# Epoch 16/200
# 10/10 [==============================] - 2s 251ms/step - loss: 0.2487 - mean_iou_threshold: 0.7735 - val_loss: 0.9570 - val_mean_iou_threshold: 0.3842
# Epoch 17/200
# 10/10 [==============================] - 2s 250ms/step - loss: 0.2407 - mean_iou_threshold: 0.7818 - val_loss: 1.2613 - val_mean_iou_threshold: 0.3842
# Epoch 18/200
# 10/10 [==============================] - 2s 250ms/step - loss: 0.2244 - mean_iou_threshold: 0.7887 - val_loss: 1.3477 - val_mean_iou_threshold: 0.3842
# Epoch 19/200
# 10/10 [==============================] - 2s 251ms/step - loss: 0.2130 - mean_iou_threshold: 0.8037 - val_loss: 1.3369 - val_mean_iou_threshold: 0.3842
# Epoch 20/200
# 10/10 [==============================] - 2s 250ms/step - loss: 0.2088 - mean_iou_threshold: 0.7990 - val_loss: 0.9939 - val_mean_iou_threshold: 0.3850
# Epoch 21/200
# 10/10 [==============================] - 3s 255ms/step - loss: 0.1968 - mean_iou_threshold: 0.8135 - val_loss: 1.1681 - val_mean_iou_threshold: 0.3858
# Epoch 22/200
# 10/10 [==============================] - 3s 258ms/step - loss: 0.1882 - mean_iou_threshold: 0.8132 - val_loss: 1.3189 - val_mean_iou_threshold: 0.3843
# Epoch 23/200
# 10/10 [==============================] - 3s 258ms/step - loss: 0.1828 - mean_iou_threshold: 0.8208 - val_loss: 1.7026 - val_mean_iou_threshold: 0.3843
# Epoch 24/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.1772 - mean_iou_threshold: 0.8252 - val_loss: 1.4506 - val_mean_iou_threshold: 0.3875
# Epoch 25/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.1734 - mean_iou_threshold: 0.8235 - val_loss: 1.2297 - val_mean_iou_threshold: 0.3868
# Epoch 26/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.1650 - mean_iou_threshold: 0.8324 - val_loss: 1.4969 - val_mean_iou_threshold: 0.3880
# Epoch 27/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.1579 - mean_iou_threshold: 0.8366 - val_loss: 1.6912 - val_mean_iou_threshold: 0.3885
# Epoch 28/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.1506 - mean_iou_threshold: 0.8435 - val_loss: 1.4942 - val_mean_iou_threshold: 0.4158
# Epoch 29/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.1434 - mean_iou_threshold: 0.8451 - val_loss: 1.7081 - val_mean_iou_threshold: 0.4047
# Epoch 30/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.1472 - mean_iou_threshold: 0.8471 - val_loss: 1.5131 - val_mean_iou_threshold: 0.4263
# Epoch 31/200
# 10/10 [==============================] - 3s 255ms/step - loss: 0.1396 - mean_iou_threshold: 0.8542 - val_loss: 1.4600 - val_mean_iou_threshold: 0.4157
# Epoch 32/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.1280 - mean_iou_threshold: 0.8602 - val_loss: 1.3601 - val_mean_iou_threshold: 0.4354
# Epoch 33/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.1184 - mean_iou_threshold: 0.8676 - val_loss: 1.2471 - val_mean_iou_threshold: 0.4493
# Epoch 34/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.1116 - mean_iou_threshold: 0.8744 - val_loss: 1.0278 - val_mean_iou_threshold: 0.5238
# Epoch 35/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.1070 - mean_iou_threshold: 0.8721 - val_loss: 1.3227 - val_mean_iou_threshold: 0.4870
# Epoch 36/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.1108 - mean_iou_threshold: 0.8702 - val_loss: 0.8341 - val_mean_iou_threshold: 0.5866
# Epoch 37/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.1085 - mean_iou_threshold: 0.8794 - val_loss: 1.0039 - val_mean_iou_threshold: 0.5592
# Epoch 38/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.1023 - mean_iou_threshold: 0.8779 - val_loss: 1.0873 - val_mean_iou_threshold: 0.5387
# Epoch 39/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0988 - mean_iou_threshold: 0.8833 - val_loss: 0.9573 - val_mean_iou_threshold: 0.5574
# Epoch 40/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0953 - mean_iou_threshold: 0.8871 - val_loss: 0.6921 - val_mean_iou_threshold: 0.6284
# Epoch 41/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0875 - mean_iou_threshold: 0.8888 - val_loss: 0.7036 - val_mean_iou_threshold: 0.6370
# Epoch 42/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0861 - mean_iou_threshold: 0.8930 - val_loss: 0.6849 - val_mean_iou_threshold: 0.6400
# Epoch 43/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0888 - mean_iou_threshold: 0.8827 - val_loss: 0.5739 - val_mean_iou_threshold: 0.6596
# Epoch 44/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0831 - mean_iou_threshold: 0.8885 - val_loss: 0.7581 - val_mean_iou_threshold: 0.6417
# Epoch 45/200
# 10/10 [==============================] - 3s 258ms/step - loss: 0.0784 - mean_iou_threshold: 0.8976 - val_loss: 0.6476 - val_mean_iou_threshold: 0.6704
# Epoch 46/200
# 10/10 [==============================] - 3s 264ms/step - loss: 0.0829 - mean_iou_threshold: 0.8843 - val_loss: 0.7178 - val_mean_iou_threshold: 0.6518
# Epoch 47/200
# 10/10 [==============================] - 3s 257ms/step - loss: 0.0862 - mean_iou_threshold: 0.8888 - val_loss: 0.9628 - val_mean_iou_threshold: 0.6098
# Epoch 48/200
# 10/10 [==============================] - 3s 261ms/step - loss: 0.0976 - mean_iou_threshold: 0.8841 - val_loss: 0.6238 - val_mean_iou_threshold: 0.6498
# Epoch 49/200
# 10/10 [==============================] - 3s 262ms/step - loss: 0.0963 - mean_iou_threshold: 0.8853 - val_loss: 0.6773 - val_mean_iou_threshold: 0.6434
# Epoch 50/200
# 10/10 [==============================] - 3s 260ms/step - loss: 0.0831 - mean_iou_threshold: 0.8946 - val_loss: 0.6185 - val_mean_iou_threshold: 0.6670
# Epoch 51/200
# 10/10 [==============================] - 3s 255ms/step - loss: 0.0753 - mean_iou_threshold: 0.8939 - val_loss: 0.5615 - val_mean_iou_threshold: 0.6795
# Epoch 52/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0713 - mean_iou_threshold: 0.9025 - val_loss: 0.5206 - val_mean_iou_threshold: 0.6806
# Epoch 53/200
# 10/10 [==============================] - 3s 266ms/step - loss: 0.0697 - mean_iou_threshold: 0.8997 - val_loss: 0.5306 - val_mean_iou_threshold: 0.6777
# Epoch 54/200
# 10/10 [==============================] - 3s 261ms/step - loss: 0.0633 - mean_iou_threshold: 0.9052 - val_loss: 0.5233 - val_mean_iou_threshold: 0.6821
# Epoch 55/200
# 10/10 [==============================] - 3s 265ms/step - loss: 0.0632 - mean_iou_threshold: 0.8961 - val_loss: 0.5587 - val_mean_iou_threshold: 0.6872
# Epoch 56/200
# 10/10 [==============================] - 3s 261ms/step - loss: 0.0628 - mean_iou_threshold: 0.9089 - val_loss: 0.5496 - val_mean_iou_threshold: 0.6843
# Epoch 57/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0622 - mean_iou_threshold: 0.9023 - val_loss: 0.5429 - val_mean_iou_threshold: 0.6827
# Epoch 58/200
# 10/10 [==============================] - 2s 251ms/step - loss: 0.0587 - mean_iou_threshold: 0.9045 - val_loss: 0.5682 - val_mean_iou_threshold: 0.6736
# Epoch 59/200
# 10/10 [==============================] - 3s 255ms/step - loss: 0.0594 - mean_iou_threshold: 0.9061 - val_loss: 0.5616 - val_mean_iou_threshold: 0.6662
# Epoch 60/200
# 10/10 [==============================] - 3s 257ms/step - loss: 0.0608 - mean_iou_threshold: 0.9034 - val_loss: 0.5698 - val_mean_iou_threshold: 0.6765
# Epoch 61/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0593 - mean_iou_threshold: 0.9046 - val_loss: 0.5542 - val_mean_iou_threshold: 0.6806
# Epoch 62/200
# 10/10 [==============================] - 3s 256ms/step - loss: 0.0569 - mean_iou_threshold: 0.9039 - val_loss: 0.6072 - val_mean_iou_threshold: 0.6636
# Epoch 63/200
# 10/10 [==============================] - 3s 258ms/step - loss: 0.0572 - mean_iou_threshold: 0.9089 - val_loss: 0.5544 - val_mean_iou_threshold: 0.6654
# Epoch 64/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0614 - mean_iou_threshold: 0.9028 - val_loss: 0.5646 - val_mean_iou_threshold: 0.6786
# Epoch 65/200
# 10/10 [==============================] - 3s 258ms/step - loss: 0.0611 - mean_iou_threshold: 0.9051 - val_loss: 0.5419 - val_mean_iou_threshold: 0.6817
# Epoch 66/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0605 - mean_iou_threshold: 0.9094 - val_loss: 0.5661 - val_mean_iou_threshold: 0.6794
# Epoch 67/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0568 - mean_iou_threshold: 0.9069 - val_loss: 0.5953 - val_mean_iou_threshold: 0.6661
# Epoch 68/200
# 10/10 [==============================] - 3s 255ms/step - loss: 0.0539 - mean_iou_threshold: 0.9103 - val_loss: 0.5932 - val_mean_iou_threshold: 0.6672
# Epoch 69/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0529 - mean_iou_threshold: 0.9071 - val_loss: 0.5835 - val_mean_iou_threshold: 0.6913
# Epoch 70/200
# 10/10 [==============================] - 2s 250ms/step - loss: 0.0523 - mean_iou_threshold: 0.9119 - val_loss: 0.5952 - val_mean_iou_threshold: 0.6853
# Epoch 71/200
# 10/10 [==============================] - 2s 250ms/step - loss: 0.0514 - mean_iou_threshold: 0.9103 - val_loss: 0.6007 - val_mean_iou_threshold: 0.6905
# Epoch 72/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0507 - mean_iou_threshold: 0.9105 - val_loss: 0.6358 - val_mean_iou_threshold: 0.6768
# Epoch 73/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0514 - mean_iou_threshold: 0.9106 - val_loss: 0.6126 - val_mean_iou_threshold: 0.6780
# Epoch 74/200
# 10/10 [==============================] - 3s 251ms/step - loss: 0.0498 - mean_iou_threshold: 0.9111 - val_loss: 0.6170 - val_mean_iou_threshold: 0.6762
# Epoch 75/200
# 10/10 [==============================] - 3s 260ms/step - loss: 0.0481 - mean_iou_threshold: 0.9074 - val_loss: 0.6321 - val_mean_iou_threshold: 0.6684
# Epoch 76/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0482 - mean_iou_threshold: 0.9103 - val_loss: 0.6672 - val_mean_iou_threshold: 0.6638
# Epoch 77/200
# 10/10 [==============================] - 3s 256ms/step - loss: 0.0495 - mean_iou_threshold: 0.9114 - val_loss: 0.6284 - val_mean_iou_threshold: 0.6768
# Epoch 78/200
# 10/10 [==============================] - 3s 259ms/step - loss: 0.0488 - mean_iou_threshold: 0.9132 - val_loss: 0.6545 - val_mean_iou_threshold: 0.6667
# Epoch 79/200
# 10/10 [==============================] - 3s 256ms/step - loss: 0.0466 - mean_iou_threshold: 0.9127 - val_loss: 0.6807 - val_mean_iou_threshold: 0.6637
# Epoch 80/200
# 10/10 [==============================] - 3s 257ms/step - loss: 0.0454 - mean_iou_threshold: 0.9131 - val_loss: 0.6832 - val_mean_iou_threshold: 0.6561
# Epoch 81/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0445 - mean_iou_threshold: 0.9148 - val_loss: 0.6703 - val_mean_iou_threshold: 0.6621
# Epoch 82/200
# 10/10 [==============================] - 3s 270ms/step - loss: 0.0447 - mean_iou_threshold: 0.9099 - val_loss: 0.6846 - val_mean_iou_threshold: 0.6573
# Epoch 83/200
# 10/10 [==============================] - 3s 267ms/step - loss: 0.0460 - mean_iou_threshold: 0.9096 - val_loss: 0.6568 - val_mean_iou_threshold: 0.6614
# Epoch 84/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0458 - mean_iou_threshold: 0.9141 - val_loss: 0.6473 - val_mean_iou_threshold: 0.6773
# Epoch 85/200
# 10/10 [==============================] - 3s 257ms/step - loss: 0.0443 - mean_iou_threshold: 0.9144 - val_loss: 0.6867 - val_mean_iou_threshold: 0.6610
# Epoch 86/200
# 10/10 [==============================] - 3s 255ms/step - loss: 0.0428 - mean_iou_threshold: 0.9086 - val_loss: 0.6859 - val_mean_iou_threshold: 0.6717
# Epoch 87/200
# 10/10 [==============================] - 3s 258ms/step - loss: 0.0420 - mean_iou_threshold: 0.9139 - val_loss: 0.7002 - val_mean_iou_threshold: 0.6718
# Epoch 88/200
# 10/10 [==============================] - 3s 256ms/step - loss: 0.0421 - mean_iou_threshold: 0.9113 - val_loss: 0.7140 - val_mean_iou_threshold: 0.6537
# Epoch 89/200
# 10/10 [==============================] - 3s 255ms/step - loss: 0.0429 - mean_iou_threshold: 0.9126 - val_loss: 0.6938 - val_mean_iou_threshold: 0.6666
# Epoch 90/200
# 10/10 [==============================] - 3s 258ms/step - loss: 0.0425 - mean_iou_threshold: 0.9119 - val_loss: 0.7033 - val_mean_iou_threshold: 0.6675
# Epoch 91/200
# 10/10 [==============================] - 3s 258ms/step - loss: 0.0425 - mean_iou_threshold: 0.9150 - val_loss: 0.7143 - val_mean_iou_threshold: 0.6696
# Epoch 92/200
# 10/10 [==============================] - 3s 255ms/step - loss: 0.0428 - mean_iou_threshold: 0.9150 - val_loss: 0.7036 - val_mean_iou_threshold: 0.6649
# Epoch 93/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0412 - mean_iou_threshold: 0.9137 - val_loss: 0.6870 - val_mean_iou_threshold: 0.6679
# Epoch 94/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0428 - mean_iou_threshold: 0.9089 - val_loss: 0.7385 - val_mean_iou_threshold: 0.6639
# Epoch 95/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0500 - mean_iou_threshold: 0.9162 - val_loss: 0.6332 - val_mean_iou_threshold: 0.6819
# Epoch 96/200
# 10/10 [==============================] - 3s 255ms/step - loss: 0.0466 - mean_iou_threshold: 0.9123 - val_loss: 0.6826 - val_mean_iou_threshold: 0.6564
# Epoch 97/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0452 - mean_iou_threshold: 0.9136 - val_loss: 0.6763 - val_mean_iou_threshold: 0.6633
# Epoch 98/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0428 - mean_iou_threshold: 0.9149 - val_loss: 0.6971 - val_mean_iou_threshold: 0.6568
# Epoch 99/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0423 - mean_iou_threshold: 0.9153 - val_loss: 0.6687 - val_mean_iou_threshold: 0.6623
# Epoch 100/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0410 - mean_iou_threshold: 0.9154 - val_loss: 0.6848 - val_mean_iou_threshold: 0.6611
# Epoch 101/200
# 10/10 [==============================] - 3s 264ms/step - loss: 0.0390 - mean_iou_threshold: 0.9147 - val_loss: 0.7223 - val_mean_iou_threshold: 0.6597
# Epoch 102/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0399 - mean_iou_threshold: 0.9148 - val_loss: 0.7032 - val_mean_iou_threshold: 0.6585
# Epoch 103/200
# 10/10 [==============================] - 3s 265ms/step - loss: 0.0391 - mean_iou_threshold: 0.9150 - val_loss: 0.6971 - val_mean_iou_threshold: 0.6719
# Epoch 104/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0393 - mean_iou_threshold: 0.9155 - val_loss: 0.7218 - val_mean_iou_threshold: 0.6606
# Epoch 105/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0390 - mean_iou_threshold: 0.9150 - val_loss: 0.7190 - val_mean_iou_threshold: 0.6666
# Epoch 106/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0384 - mean_iou_threshold: 0.9158 - val_loss: 0.7171 - val_mean_iou_threshold: 0.6621
# Epoch 107/200
# 10/10 [==============================] - 3s 272ms/step - loss: 0.0386 - mean_iou_threshold: 0.9155 - val_loss: 0.7243 - val_mean_iou_threshold: 0.6632
# Epoch 108/200
# 10/10 [==============================] - 3s 259ms/step - loss: 0.0383 - mean_iou_threshold: 0.9148 - val_loss: 0.7159 - val_mean_iou_threshold: 0.6670
# Epoch 109/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0382 - mean_iou_threshold: 0.9164 - val_loss: 0.7602 - val_mean_iou_threshold: 0.6585
# Epoch 110/200
# 10/10 [==============================] - 3s 258ms/step - loss: 0.0382 - mean_iou_threshold: 0.9145 - val_loss: 0.7343 - val_mean_iou_threshold: 0.6701
# Epoch 111/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0380 - mean_iou_threshold: 0.9148 - val_loss: 0.7197 - val_mean_iou_threshold: 0.6684
# Epoch 112/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0370 - mean_iou_threshold: 0.9150 - val_loss: 0.7382 - val_mean_iou_threshold: 0.6672
# Epoch 113/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0387 - mean_iou_threshold: 0.9153 - val_loss: 0.7655 - val_mean_iou_threshold: 0.6697
# Epoch 114/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0384 - mean_iou_threshold: 0.9163 - val_loss: 0.7089 - val_mean_iou_threshold: 0.6784
# Epoch 115/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0396 - mean_iou_threshold: 0.9140 - val_loss: 0.7235 - val_mean_iou_threshold: 0.6615
# Epoch 116/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0388 - mean_iou_threshold: 0.9140 - val_loss: 0.7072 - val_mean_iou_threshold: 0.6674
# Epoch 117/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0390 - mean_iou_threshold: 0.9187 - val_loss: 0.7020 - val_mean_iou_threshold: 0.6657
# Epoch 118/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0389 - mean_iou_threshold: 0.9144 - val_loss: 0.7343 - val_mean_iou_threshold: 0.6624
# Epoch 119/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0381 - mean_iou_threshold: 0.9151 - val_loss: 0.7078 - val_mean_iou_threshold: 0.6738
# Epoch 120/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0368 - mean_iou_threshold: 0.9169 - val_loss: 0.7287 - val_mean_iou_threshold: 0.6746
# Epoch 121/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0370 - mean_iou_threshold: 0.9163 - val_loss: 0.7364 - val_mean_iou_threshold: 0.6634
# Epoch 122/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0364 - mean_iou_threshold: 0.9161 - val_loss: 0.7473 - val_mean_iou_threshold: 0.6631
# Epoch 123/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0363 - mean_iou_threshold: 0.9157 - val_loss: 0.7367 - val_mean_iou_threshold: 0.6702
# Epoch 124/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0365 - mean_iou_threshold: 0.9156 - val_loss: 0.7538 - val_mean_iou_threshold: 0.6713
# Epoch 125/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0379 - mean_iou_threshold: 0.9137 - val_loss: 0.7384 - val_mean_iou_threshold: 0.6823
# Epoch 126/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0390 - mean_iou_threshold: 0.9179 - val_loss: 0.7372 - val_mean_iou_threshold: 0.6797
# Epoch 127/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0385 - mean_iou_threshold: 0.9155 - val_loss: 0.7591 - val_mean_iou_threshold: 0.6654
# Epoch 128/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0392 - mean_iou_threshold: 0.9155 - val_loss: 0.7064 - val_mean_iou_threshold: 0.6605
# Epoch 129/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0371 - mean_iou_threshold: 0.9117 - val_loss: 0.7641 - val_mean_iou_threshold: 0.6661
# Epoch 130/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0367 - mean_iou_threshold: 0.9158 - val_loss: 0.7687 - val_mean_iou_threshold: 0.6561
# Epoch 131/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0368 - mean_iou_threshold: 0.9146 - val_loss: 0.7364 - val_mean_iou_threshold: 0.6739
# Epoch 132/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0370 - mean_iou_threshold: 0.9174 - val_loss: 0.7444 - val_mean_iou_threshold: 0.6605
# Epoch 133/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0370 - mean_iou_threshold: 0.9113 - val_loss: 0.7482 - val_mean_iou_threshold: 0.6667
# Epoch 134/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0370 - mean_iou_threshold: 0.9142 - val_loss: 0.7735 - val_mean_iou_threshold: 0.6587
# Epoch 135/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0357 - mean_iou_threshold: 0.9170 - val_loss: 0.7431 - val_mean_iou_threshold: 0.6699
# Epoch 136/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0350 - mean_iou_threshold: 0.9162 - val_loss: 0.7642 - val_mean_iou_threshold: 0.6700
# Epoch 137/200
# 10/10 [==============================] - 3s 265ms/step - loss: 0.0350 - mean_iou_threshold: 0.9162 - val_loss: 0.7603 - val_mean_iou_threshold: 0.6604
# Epoch 138/200
# 10/10 [==============================] - 3s 272ms/step - loss: 0.0358 - mean_iou_threshold: 0.9143 - val_loss: 0.7844 - val_mean_iou_threshold: 0.6621
# Epoch 139/200
# 10/10 [==============================] - 3s 259ms/step - loss: 0.0356 - mean_iou_threshold: 0.9174 - val_loss: 0.7633 - val_mean_iou_threshold: 0.6589
# Epoch 140/200
# 10/10 [==============================] - 3s 267ms/step - loss: 0.0352 - mean_iou_threshold: 0.9152 - val_loss: 0.7789 - val_mean_iou_threshold: 0.6621
# Epoch 141/200
# 10/10 [==============================] - 3s 258ms/step - loss: 0.0351 - mean_iou_threshold: 0.9159 - val_loss: 0.7918 - val_mean_iou_threshold: 0.6596
# Epoch 142/200
# 10/10 [==============================] - 3s 258ms/step - loss: 0.0347 - mean_iou_threshold: 0.9171 - val_loss: 0.7841 - val_mean_iou_threshold: 0.6533
# Epoch 143/200
# 10/10 [==============================] - 3s 259ms/step - loss: 0.0352 - mean_iou_threshold: 0.9156 - val_loss: 0.7634 - val_mean_iou_threshold: 0.6674
# Epoch 144/200
# 10/10 [==============================] - 3s 262ms/step - loss: 0.0350 - mean_iou_threshold: 0.9165 - val_loss: 0.7627 - val_mean_iou_threshold: 0.6671
# Epoch 145/200
# 10/10 [==============================] - 3s 260ms/step - loss: 0.0346 - mean_iou_threshold: 0.9156 - val_loss: 0.7906 - val_mean_iou_threshold: 0.6637
# Epoch 146/200
# 10/10 [==============================] - 3s 255ms/step - loss: 0.0346 - mean_iou_threshold: 0.9173 - val_loss: 0.7735 - val_mean_iou_threshold: 0.6610
# Epoch 147/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0351 - mean_iou_threshold: 0.9162 - val_loss: 0.7710 - val_mean_iou_threshold: 0.6603
# Epoch 148/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0349 - mean_iou_threshold: 0.9165 - val_loss: 0.7632 - val_mean_iou_threshold: 0.6697
# Epoch 149/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0348 - mean_iou_threshold: 0.9172 - val_loss: 0.7877 - val_mean_iou_threshold: 0.6512
# Epoch 150/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0354 - mean_iou_threshold: 0.9146 - val_loss: 0.7753 - val_mean_iou_threshold: 0.6639
# Epoch 151/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0353 - mean_iou_threshold: 0.9173 - val_loss: 0.7658 - val_mean_iou_threshold: 0.6682
# Epoch 152/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0355 - mean_iou_threshold: 0.9175 - val_loss: 0.7678 - val_mean_iou_threshold: 0.6688
# Epoch 153/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0360 - mean_iou_threshold: 0.9162 - val_loss: 0.7511 - val_mean_iou_threshold: 0.6693
# Epoch 154/200
# 10/10 [==============================] - 3s 256ms/step - loss: 0.0357 - mean_iou_threshold: 0.9153 - val_loss: 0.7436 - val_mean_iou_threshold: 0.6733
# Epoch 155/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0353 - mean_iou_threshold: 0.9121 - val_loss: 0.7635 - val_mean_iou_threshold: 0.6673
# Epoch 156/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0355 - mean_iou_threshold: 0.9166 - val_loss: 0.7826 - val_mean_iou_threshold: 0.6748
# Epoch 157/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0359 - mean_iou_threshold: 0.9137 - val_loss: 0.7751 - val_mean_iou_threshold: 0.6700
# Epoch 158/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0354 - mean_iou_threshold: 0.9163 - val_loss: 0.7528 - val_mean_iou_threshold: 0.6733
# Epoch 159/200
# 10/10 [==============================] - 3s 251ms/step - loss: 0.0348 - mean_iou_threshold: 0.9155 - val_loss: 0.7947 - val_mean_iou_threshold: 0.6663
# Epoch 160/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0345 - mean_iou_threshold: 0.9171 - val_loss: 0.7984 - val_mean_iou_threshold: 0.6638
# Epoch 161/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0345 - mean_iou_threshold: 0.9156 - val_loss: 0.7744 - val_mean_iou_threshold: 0.6588
# Epoch 162/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0349 - mean_iou_threshold: 0.9143 - val_loss: 0.7868 - val_mean_iou_threshold: 0.6727
# Epoch 163/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0352 - mean_iou_threshold: 0.9175 - val_loss: 0.7704 - val_mean_iou_threshold: 0.6654
# Epoch 164/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0343 - mean_iou_threshold: 0.9151 - val_loss: 0.7802 - val_mean_iou_threshold: 0.6730
# Epoch 165/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0354 - mean_iou_threshold: 0.9179 - val_loss: 0.7901 - val_mean_iou_threshold: 0.6574
# Epoch 166/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0353 - mean_iou_threshold: 0.9080 - val_loss: 0.7982 - val_mean_iou_threshold: 0.6696
# Epoch 167/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0346 - mean_iou_threshold: 0.9160 - val_loss: 0.7733 - val_mean_iou_threshold: 0.6688
# Epoch 168/200
# 10/10 [==============================] - 3s 259ms/step - loss: 0.0340 - mean_iou_threshold: 0.9175 - val_loss: 0.7837 - val_mean_iou_threshold: 0.6743
# Epoch 169/200
# 10/10 [==============================] - 3s 261ms/step - loss: 0.0343 - mean_iou_threshold: 0.9149 - val_loss: 0.8177 - val_mean_iou_threshold: 0.6622
# Epoch 170/200
# 10/10 [==============================] - 3s 265ms/step - loss: 0.0335 - mean_iou_threshold: 0.9164 - val_loss: 0.7907 - val_mean_iou_threshold: 0.6668
# Epoch 171/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0334 - mean_iou_threshold: 0.9166 - val_loss: 0.7844 - val_mean_iou_threshold: 0.6665
# Epoch 172/200
# 10/10 [==============================] - 3s 255ms/step - loss: 0.0337 - mean_iou_threshold: 0.9153 - val_loss: 0.8150 - val_mean_iou_threshold: 0.6647
# Epoch 173/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0335 - mean_iou_threshold: 0.9169 - val_loss: 0.7754 - val_mean_iou_threshold: 0.6653
# Epoch 174/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0334 - mean_iou_threshold: 0.9118 - val_loss: 0.7968 - val_mean_iou_threshold: 0.6685
# Epoch 175/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0337 - mean_iou_threshold: 0.9166 - val_loss: 0.8056 - val_mean_iou_threshold: 0.6595
# Epoch 176/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0338 - mean_iou_threshold: 0.9156 - val_loss: 0.7860 - val_mean_iou_threshold: 0.6723
# Epoch 177/200
# 10/10 [==============================] - 3s 265ms/step - loss: 0.0335 - mean_iou_threshold: 0.9169 - val_loss: 0.7999 - val_mean_iou_threshold: 0.6608
# Epoch 178/200
# 10/10 [==============================] - 3s 276ms/step - loss: 0.0329 - mean_iou_threshold: 0.9157 - val_loss: 0.7999 - val_mean_iou_threshold: 0.6686
# Epoch 179/200
# 10/10 [==============================] - 3s 268ms/step - loss: 0.0327 - mean_iou_threshold: 0.9156 - val_loss: 0.8162 - val_mean_iou_threshold: 0.6674
# Epoch 180/200
# 10/10 [==============================] - 3s 275ms/step - loss: 0.0331 - mean_iou_threshold: 0.9159 - val_loss: 0.7949 - val_mean_iou_threshold: 0.6645
# Epoch 181/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0328 - mean_iou_threshold: 0.9151 - val_loss: 0.8099 - val_mean_iou_threshold: 0.6702
# Epoch 182/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0326 - mean_iou_threshold: 0.9174 - val_loss: 0.8300 - val_mean_iou_threshold: 0.6570
# Epoch 183/200
# 10/10 [==============================] - 3s 257ms/step - loss: 0.0328 - mean_iou_threshold: 0.9160 - val_loss: 0.8025 - val_mean_iou_threshold: 0.6675
# Epoch 184/200
# 10/10 [==============================] - 3s 254ms/step - loss: 0.0325 - mean_iou_threshold: 0.9185 - val_loss: 0.8051 - val_mean_iou_threshold: 0.6704
# Epoch 185/200
# 10/10 [==============================] - 3s 309ms/step - loss: 0.0325 - mean_iou_threshold: 0.9161 - val_loss: 0.8172 - val_mean_iou_threshold: 0.6659
# Epoch 186/200
# 10/10 [==============================] - 3s 261ms/step - loss: 0.0330 - mean_iou_threshold: 0.9157 - val_loss: 0.7864 - val_mean_iou_threshold: 0.6706
# Epoch 187/200
# 10/10 [==============================] - 3s 262ms/step - loss: 0.0332 - mean_iou_threshold: 0.9107 - val_loss: 0.8148 - val_mean_iou_threshold: 0.6784
# Epoch 188/200
# 10/10 [==============================] - 3s 264ms/step - loss: 0.0331 - mean_iou_threshold: 0.9175 - val_loss: 0.8153 - val_mean_iou_threshold: 0.6667
# Epoch 189/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0331 - mean_iou_threshold: 0.9152 - val_loss: 0.7940 - val_mean_iou_threshold: 0.6710
# Epoch 190/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0326 - mean_iou_threshold: 0.9165 - val_loss: 0.8111 - val_mean_iou_threshold: 0.6687
# Epoch 191/200
# 10/10 [==============================] - 3s 264ms/step - loss: 0.0324 - mean_iou_threshold: 0.9125 - val_loss: 0.7888 - val_mean_iou_threshold: 0.6704
# Epoch 192/200
# 10/10 [==============================] - 3s 268ms/step - loss: 0.0325 - mean_iou_threshold: 0.9170 - val_loss: 0.8452 - val_mean_iou_threshold: 0.6624
# Epoch 193/200
# 10/10 [==============================] - 3s 268ms/step - loss: 0.0325 - mean_iou_threshold: 0.9172 - val_loss: 0.7911 - val_mean_iou_threshold: 0.6718
# Epoch 194/200
# 10/10 [==============================] - 3s 264ms/step - loss: 0.0325 - mean_iou_threshold: 0.9180 - val_loss: 0.8119 - val_mean_iou_threshold: 0.6679
# Epoch 195/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0328 - mean_iou_threshold: 0.9155 - val_loss: 0.8116 - val_mean_iou_threshold: 0.6661
# Epoch 196/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0329 - mean_iou_threshold: 0.9163 - val_loss: 0.8239 - val_mean_iou_threshold: 0.6612
# Epoch 197/200
# 10/10 [==============================] - 3s 263ms/step - loss: 0.0329 - mean_iou_threshold: 0.9154 - val_loss: 0.8235 - val_mean_iou_threshold: 0.6676
# Epoch 198/200
# 10/10 [==============================] - 3s 264ms/step - loss: 0.0331 - mean_iou_threshold: 0.9165 - val_loss: 0.8299 - val_mean_iou_threshold: 0.6653
# Epoch 199/200
# 10/10 [==============================] - 3s 262ms/step - loss: 0.0327 - mean_iou_threshold: 0.9160 - val_loss: 0.8360 - val_mean_iou_threshold: 0.6694
# Epoch 200/200
# 10/10 [==============================] - 3s 264ms/step - loss: 0.0325 - mean_iou_threshold: 0.9153 - val_loss: 0.8337 - val_mean_iou_threshold: 0.6683

# %%
val_preds = model.predict(np.array([trainImgs[0]]))

# %%
val_preds.shape
# Out:
# (1, 128, 128, 1)

# %%
def display_mask(img):
    """Quick utility to display a model's prediction."""
    predict_img = img
    predict_img[predict_img > threshold] = 1
    predict_img[predict_img <= threshold] = 0

    predict_img_original_size = cv2.resize(
        predict_img,
        (128, 128),
        interpolation=cv2.INTER_NEAREST
    )
    predict_img_original_size = predict_img_original_size * 255.0
    plt.imshow(predict_img_original_size, cmap=plt.cm.binary)

# %%
# Display input image
plt.imshow(trainImgs[0])

# %%
# Display ground-truth target mask
display_mask(validImgs[0])

# %%
plt.imshow(val_preds[0], cmap='gray')

# %%
display_mask(val_preds[0])

# %%
def plot_result(img_pred, original, valid):
    plt.figure(figsize=(10, 10))
    n = 1
    for index, img in enumerate(img_pred):
        for i in range(3):
            plt.xticks([])
            plt.yticks([])
            plt.grid(False)
            plt.subplot(img_pred.shape[0] , 3, n)
            if i == 0:
                original_img = cv2.resize(original[index], img_size)
                plt.imshow(original_img)
                plt.xlabel("Original ")
            if i == 1:
                result_img = cv2.resize(img, img_size)
                plt.imshow(result_img, cmap=plt.cm.binary)
                plt.xlabel("Result", )
            if i == 2:
                valid_img = cv2.resize(valid[index], img_size)
                plt.imshow(valid_img, cmap=plt.cm.binary)
                plt.xlabel("Expected")
            n += 1

# %%
path_healthy_img = '../dataset/segmentation/healthy/'
path_healthy_val = '../dataset/segmentation/annotation/healthy/'

healthy_img = load_all_imgs(path_healthy_img, img_size, 1)
healthy_val = load_all_imgs(path_healthy_val, img_size, 0)
healthy_pred = model.predict(healthy_img)
# ----- Primeiras 5 Imagens -----
plot_result(healthy_pred[:5], healthy_img[:5], healthy_val[:5])
# ----- Ultimas 5 Imagens -----
plot_result(healthy_pred[-5:], healthy_img[-5:], healthy_val[-5:])
# Out:
# ../dataset/segmentation/healthy/ found 30 img to load
#
# [0]:|||||||||||||||||||||||||||||
# ../dataset/segmentation/annotation/healthy/ found 30 img to load
#
# [0]:|||||||||||||||||||||||||||||

# %%
path_mild_img = '../dataset/segmentation/mild/'
path_mild_val = '../dataset/segmentation/annotation/mild/'

mild_img = load_all_imgs(path_mild_img, img_size, 1)
mild_val = load_all_imgs(path_mild_val, img_size, 0)
mild_pred = model.predict(mild_img)
# ----- Primeiras 5 Imagens -----
plot_result(mild_pred[:5], mild_img[:5], mild_val[:5])
# ----- Ultimas 5 Imagens -----
plot_result(mild_pred[-5:], mild_img[-5:], mild_val[-5:])
# Out:
# ../dataset/segmentation/mild/ found 30 img to load
#
# [0]:|||||||||||||||||||||||||||||
# ../dataset/segmentation/annotation/mild/ found 30 img to load
#
# [0]:|||||||||||||||||||||||||||||

# %%
pred_imgs = trainImgs[-5:]
pred_valid = validImgs[-5:]
severe_pred = model.predict(pred_imgs)

plot_result(severe_pred, pred_imgs, pred_valid)

# %%
pred_imgs = trainImgs[61:67]
pred_valid = validImgs[61:67]
val_preds = model.predict(pred_imgs)
plot_result(val_preds, pred_imgs, pred_valid)
