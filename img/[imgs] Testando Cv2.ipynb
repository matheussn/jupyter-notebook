# %%
# %matplotlib inline
import os

import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('../dataset/teste.png')
b,g,r = cv2.split(img)
original = cv2.merge([r,g,b])

# %%
original.shape
# Out:
# (64, 64, 3)

# %%
plt.imshow(original)

# %%
original
# Out:
# array([[[158, 178, 203],
#         [161, 181, 208],
#         [155, 175, 202],
#         ...,
#         [140, 172, 195],
#         [134, 164, 192],
#         [125, 151, 184]],
#
#        [[162, 182, 207],
#         [155, 175, 200],
#         [154, 174, 201],
#         ...,
#         [133, 168, 190],
#         [109, 140, 168],
#         [ 86, 115, 145]],
#
#        [[159, 179, 204],
#         [158, 178, 203],
#         [145, 165, 192],
#         ...,
#         [126, 160, 185],
#         [ 85, 116, 144],
#         [ 80, 109, 139]],
#
#        ...,
#
#        [[145, 167, 206],
#         [142, 162, 199],
#         [141, 159, 197],
#         ...,
#         [113, 110, 157],
#         [133, 130, 177],
#         [114, 114, 164]],
#
#        [[137, 159, 198],
#         [133, 153, 190],
#         [139, 157, 195],
#         ...,
#         [127, 121, 169],
#         [137, 134, 181],
#         [112, 112, 162]],
#
#        [[126, 145, 185],
#         [128, 146, 184],
#         [133, 151, 189],
# ...

# %%
rgb_img = original / 255.

# %%
plt.imshow(rgb_img)

# %%
rgb_img
# Out:
# array([[[0.61960784, 0.69803922, 0.79607843],
#         [0.63137255, 0.70980392, 0.81568627],
#         [0.60784314, 0.68627451, 0.79215686],
#         ...,
#         [0.54901961, 0.6745098 , 0.76470588],
#         [0.5254902 , 0.64313725, 0.75294118],
#         [0.49019608, 0.59215686, 0.72156863]],
#
#        [[0.63529412, 0.71372549, 0.81176471],
#         [0.60784314, 0.68627451, 0.78431373],
#         [0.60392157, 0.68235294, 0.78823529],
#         ...,
#         [0.52156863, 0.65882353, 0.74509804],
#         [0.42745098, 0.54901961, 0.65882353],
#         [0.3372549 , 0.45098039, 0.56862745]],
#
#        [[0.62352941, 0.70196078, 0.8       ],
#         [0.61960784, 0.69803922, 0.79607843],
#         [0.56862745, 0.64705882, 0.75294118],
#         ...,
#         [0.49411765, 0.62745098, 0.7254902 ],
#         [0.33333333, 0.45490196, 0.56470588],
#         [0.31372549, 0.42745098, 0.54509804]],
#
#        ...,
#
#        [[0.56862745, 0.65490196, 0.80784314],
# ...

# %%
img_pos = (original / 127.5) - 1

# %%
img_pos
# Out:
# array([[[ 0.23921569,  0.39607843,  0.59215686],
#         [ 0.2627451 ,  0.41960784,  0.63137255],
#         [ 0.21568627,  0.37254902,  0.58431373],
#         ...,
#         [ 0.09803922,  0.34901961,  0.52941176],
#         [ 0.05098039,  0.28627451,  0.50588235],
#         [-0.01960784,  0.18431373,  0.44313725]],
#
#        [[ 0.27058824,  0.42745098,  0.62352941],
#         [ 0.21568627,  0.37254902,  0.56862745],
#         [ 0.20784314,  0.36470588,  0.57647059],
#         ...,
#         [ 0.04313725,  0.31764706,  0.49019608],
#         [-0.14509804,  0.09803922,  0.31764706],
#         [-0.3254902 , -0.09803922,  0.1372549 ]],
#
#        [[ 0.24705882,  0.40392157,  0.6       ],
#         [ 0.23921569,  0.39607843,  0.59215686],
#         [ 0.1372549 ,  0.29411765,  0.50588235],
#         ...,
#         [-0.01176471,  0.25490196,  0.45098039],
#         [-0.33333333, -0.09019608,  0.12941176],
#         [-0.37254902, -0.14509804,  0.09019608]],
#
#        ...,
#
# ...

# %%
plt.imshow(img_pos)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(0.5 * img_pos + 0.5)

# %%
img_test = 0.5 * img_pos + 0.5
img_test = (img_test + 1) / 2.
plt.imshow(img_test)

# %%
img_test_2 = (img_pos + 1) / 2.
plt.imshow(img_test_2)
